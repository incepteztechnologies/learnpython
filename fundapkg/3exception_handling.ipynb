# %%
try:
    print("write any line of codes")
except Exception:
    print("something went wrong")
# Out:
# write any line of codes

# %%
age = input("Enter age: ")
citizen = input("Are you an Indian citizen? (yes/no)")
print(age)
print(citizen.lower())
if age >= "18" and citizen.lower() == "yes":
    print("Eligible to vote")
else:
    print("Not eligible")
# Out:
# 18
# yes
# Not eligible

# %%
#This is not so much important as like what we learned so far, how ever good to know once..
#Avoiding un expected termination of a program abruptly and to handle it we use exception.
#Minimum every program we write need to have minimum exception handling using try & except block
curtime=9
etc=13
import time
try:#any error in any line of code inside try, then except block will run
    while curtime<=etc:
        print("Irfan will do experience transfer until",etc,"cur time is",curtime)
        time.sleep(2)
        curtime = curtime+'a'#Program failed, control will be taken to except block
        print("if everything is good in the above list of statements, control of the program is transferred to here")
except Exception as err_message:
    print(f"something went wrong {err_message}")
    print("mail: the file not present {err_message}")
# Out:
# Irfan will do experience transfer until 13 cur time is 9
# something went wrong unsupported operand type(s) for +: 'int' and 'str'
# mail: the file not present {err_message}

# %%
try:
    age=int(input("Enter your age: "))
    if age <13:#Starting of a block is :
        print("You are kid")
        print("I will get choclates for u")#ending of a sub block using indend
    elif age>12 and age<20:
        print("You are a teenager")
        print("I will get gadgets for u")#ending of a sub block using indend
    elif age>=20 and age<40:
        print("You are a middle age man")
    print("next block started here")#start of a new block using indend
    age=age/0
#except ZeroDivisionError as err_message:
#    print(f"some number error occured {err_message}")
except Exception as err_message:
    print(f"something went wrong : {err_message}")
# Out:
# You are a teenager
# I will get gadgets for u
# next block started here
# something went wrong : division by zero

# %%
curtime=9
etc=13
import time
while curtime<=etc:#If anything went wrong, the program will terminate and come out abruptly
        print("Irfan will do experience transfer until",etc,"cur time is",curtime)
        time.sleep(2)
        curtime = curtime+'a'

print("if everything is good in the above list of statements, control of the program is transferred to here")
# Out:
# Irfan will do experience transfer until 13 cur time is 9
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 7
#       3 import time
#       4 while curtime<=etc:#If anything went wrong, the program will terminate and come out abruptly
#       5         print("Irfan will do experience transfer until",etc,"cur time is",curtime)
#       6         time.sleep(2)
# ----> 7         curtime = curtime+'a'
#       8
#       9 print("if everything is good in the above list of statements, control of the program is transferred to here")
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
# Out:
# write any line of codes
