# %% [markdown]
# **1. What is an Exception & Different ways of handling exceptions**

# %%
#Exception - Abnormal termination of the program due to some errors (100 of errors are there)
#Exception Handler - Graceful handling of exceptions using multiple methodologies
# 1. Handling the error gracefully & stop the application after handling it (logging, notification, cleanup).
# 2. Set some default values and exit the application
# 3. Continue the application with the next iteration without terminating the application

# %%
try:
    print("write any line of codes")
except Exception:
    print("something went wrong")
# Out:
# write any line of codes

# %%
# 1. Handling the error gracefully & stop the application after handling it (notification, cleanup).
import os
try:
    print("Write some lines of code to read data from DB and write to files D:\\dbdata")
    100/0#Zero division error
except Exception as errmsg:
    #Handling exception by logging/notifying/cleaning/rollbacking etc.,
    print("Mail Sent: something went wrong:",errmsg)
    os.rmdir("D:\\dbdata")
# Out:
# Write some lines of code to read data from DB and write to files D:\dbdata
# Mail Sent: something went wrong: division by zero

# %%
# 2. Set some default values and exit the application
try:
        age = int(input("Enter age: "))
        print(f"age given by user: {age}")
except Exception as err_message:
        print(f"something went wrong : {err_message}")
        print("setting the age to default value to proceed further")
        age=1#Handling exception by setting default value
        print(f"age set by the system due to exception: {age}")
# Out:
# age given by user: 200
# something went wrong :
# setting the age to default value to proceed further
# age set by the system due to exception: 115

# %%
# 3. Continue the application with the next iteration without terminating the application
while True:
    try:
            age = int(input("Enter age: "))
            print(f"age given by user: {age}")
            assert age<=115,"Unexpected Age value, should be less than 115" #If this check is failed (age>115 means then exception occurs)
            print("Program completed successfully, without any exception")
            break
    except Exception as err_message:
            print(f"something went wrong : {err_message}")
# Out:
# age given by user: 120
# something went wrong : Unexpected Age value, should be less than 115
# age given by user: 119
# something went wrong : Unexpected Age value, should be less than 115
# age given by user: 100
# Program completed successfully, without any exception

# %%
age='17'#loc -> 2, 3, 4, 9  # age=19#loc -> 2, 5, 6, 9 # age='17' -> 2, 3, 7, 8, 9
try:
    if age<18:
        print("not voting")
    else:
        print("voting")
except Exception as err_message:
    print(f"something went wrong : {err_message}")
print("previous block is finished with error")
# Out:
# something went wrong : '<' not supported between instances of 'str' and 'int'
# previous block is finished

# %%
age='17'#loc -> 2, 3, 4, 9  # age=19#loc -> 2, 5, 6, 9 # age='17' -> 2, 3, 7, 8, 9
try:
    age = int(age)
    if age<18:
        print("not voting")
    else:
        print("voting")
except Exception as err_message:
    print(f"something went wrong : {err_message}")
print("previous block is finished with error")

# %%
#This is not so much important as like what we learned so far, how ever good to know once..
#Avoiding un expected termination of a program abruptly and to handle it we use exception.
#Minimum every program we write need to have minimum exception handling using try & except block
curtime=9
etc=13
import time
try:#any error in any line of code inside try, then except block will run
    while curtime<=etc:
        print("Irfan will do experience transfer until",etc,"cur time is",curtime)
        time.sleep(2)
        curtime = curtime+'a'#Program failed, control will be taken to except block
        print("if everything is good in the above list of statements, control of the program is transferred to here")
except Exception as err_message:
    print(f"something went wrong {err_message}")
    print("mail: the file not present {err_message}")
# Out:
# Irfan will do experience transfer until 13 cur time is 9
# something went wrong unsupported operand type(s) for +: 'int' and 'str'
# mail: the file not present {err_message}

# %% [markdown]
# **2. Different Exception Blocks**

# %%
#Voting Example where no exception occurs
try:
    age=19
    if age>=18:
        print("Eligible for voting")
    else:
        print("Not Eligible for voting")
except Exception as err_message:#Run when try is failed
    print("something went wrong : {err_message}")
else:#Run when try is success (No exception)
    print("Else Block: Everything went fine inside the try block")
    print("Doing some cleanup, if try is successful (No exception)")
    #os.rmdir("D:\\tmp")
# Out:
# Eligible for voting
# Else Block: Everything went fine inside the try block
# Doing some cleanup, if try is successful (No exception)

# %%
#Voting Example where no exception occurs
#Conclusion of exception handling blocks:
#Try block will always executed as a first block? True
#Try block needs any one of these blocks - except block or finally block or else block? False (else alone cant work)
#Try block needs any one of these blocks - except block or finally block? True
#If Exception occurs in try then except block will be executed & else block is also executed? False (only except is executed)
#If Exception occurs in try then except block will be executed & finally block is also executed? True
#If try block is success then else block alone is executed, though i have except & finally block? False (else & finally will also execute)
#If try block is success then else block and finally block is executed? True
#else executed when no exception? True
#except executed when exception? True
#finally executed when exception or when no exception? True
try:
    age='19'
    if age>=18:
        print("Eligible for voting")
    else:
        print("Not Eligible for voting")
except Exception as err_message:#Run when try is failed
    print("Exception Block: something went wrong : {err_message}")
else:#Run when try is success
    print("Else Block: Everything went fine inside the try block")
    #os.rmdir("D:\\tmp")
finally:#Whether Run is success or failed (exception occured)
    print("Finally Block : will run at any cost")
    print("Doing some cleanup, if try is successful or failed")
    #os.rmdir("D:\\tmp")
# Out:
# Exception Block: something went wrong : {err_message}
# Finally Block : will run at any cost
# Doing some cleanup, if try is successful or failed

# %%
try:
    print("hello team")
except Exception as err_message:
    print(f"something went wrong : {err_message}")
# Out:
# hello team

# %%
try:
    print("hello team")
finally:
    print("finally i will run this")
# Out:
# hello team
# finally i will run this

# %% [markdown]
# **3. Types of Exceptions**

# %%
#Syntax Error:
if 1>0
    print("hello")
# Out:
#   Cell In[40], line 2
#     if 1>0
#           ^
# SyntaxError: expected ':'

# %%
if 1>0:
    print("line1")
 print("line2")
# Out:
#   File <string>:3
#     print("line2")
#                   ^
# IndentationError: unindent does not match any outer indentation level

# %%
#Code with unhandled exception
a=100
print(b)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[42], line 2
#       1 a=100
# ----> 2 print(b)
#
# NameError: name 'b' is not defined

# %%
#Code with exception handler
try:
    a=100
    print(b)
except NameError as err:
    print("Print the variable after defining it:",err)
# Out:
# Print the variable after defining it: name 'b' is not defined

# %%
print('irfan'+44)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 print('irfan'+44)
#
# TypeError: can only concatenate str (not "int") to str

# %%
#Code with exception handler
try:
    a=101
    #print(b)#nameerror
    #print('10'+44)#typeerror
    #print(int('hello'))#valueerror
    lst=['Saravanan','Yuvaraj']
    #print(lst[2])#indexerror
    dict1={1:'irfan',2:'saravanan',3:'Yuvaraj'}
    #print(dict1[10])#Keyerror
    #print(100/0)#ZeroDivisionError
    assert a==100,"ensure a is assigned as 100"
except NameError as err:
    print("Print the variable after defining it:",err)
except TypeError as err:
    print("Python is strongly typed language:",err)
    print(int('10')+44)
except ValueError as err:
    print("Alphabets can't be converted to int:",err)
    print(int('10')+44)
except IndexError as err:
    print("Index error :",err)
    print(lst[len(lst)-1])
except KeyError as err:
    print("Dictionary key is not found :",err)
    print("try to use only these keys:",dict1.keys())
except ZeroDivisionError as err:
    print("Denominator should'nt be zero:",err)
except AssertionError as err:
    print("Assertion error",err)
    a=100
    print(a)
except Exception as err:
    print("Some error occured",err)
# Out:
# Assertion error ensure a is assigned as 100
# 100

# %%
#Custom Exception Handler to handle
#If the predefined exceptions of the list provided is not enough to handle some specific exceptions that we want to customize. If I want to raise an exception in case it is not provided already, then we can create custom exception.
class InceptezError(Exception): #Inheritance (OOPs)
    pass
try:
    aspirants_joined=input("Enter Aspirant name:")
    aspirants_list=["Preethi","Sujithra","Nathiya","Uvaraj"]
    if aspirants_joined in aspirants_list:
        print("He/She is a registered Aspirant")
    else:
        raise InceptezError(f"You are not a registered Aspirant {aspirants_joined}")
except InceptezError  as errmsg:
    print("Error Message:",errmsg)
    print(f"Remove this aspirant from zoom meeting {aspirants_joined}")
# Out:
# Error Message: You are not a registered Aspirant Abcd

# %%
#Minimum expectation/needed from all of you
try:
    '''any line of code'''
except Exception as errmsg:
    print("error occured",errmsg)
